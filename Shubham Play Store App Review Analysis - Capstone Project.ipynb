# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# ###Step1: Import the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


# %matplotlib inline

# %% [markdown]
# ###Step2: Load the csv files from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     107       force_remount=force_remount,
#     108       timeout_ms=timeout_ms,
# --> 109       ephemeral=True)
#     110
#     111
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     122   if ephemeral:
#     123     _message.blocking_request(
# --> 124         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     125
#     126   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     173   request_id = send_request(
#     174       request_type, request, parent=parent, expect_reply=True)
# --> 175   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: Error: credential propagation was unsuccessful

# %%
path = '/content/drive/My Drive'
df_play_store =  pd.read_csv(path + '/Almabetter/App review analysis/Play Store Data.csv')
df_user_review =  pd.read_csv(path + '/Almabetter/App review analysis/User Reviews.csv')

# %% [markdown]
# ###Step3: Basic data information

# %% [markdown]
# ####1. Play Store Data

# %%
df_play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            9146 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content_Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last_Updated    10841 non-null  object
#  11  Current_Ver     10833 non-null  object
#  12  Android_Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df_play_store.describe()
# Out:
#             Rating       Reviews         Size
# count  9367.000000  1.084100e+04  9146.000000
# mean      4.193338  4.441119e+05    21.623150
# std       0.537431  2.927629e+06    24.797055
# min       1.000000  0.000000e+00     0.008301
# 25%       4.000000  3.800000e+01     4.900000
# 50%       4.300000  2.094000e+03    13.000000
# 75%       4.500000  5.476800e+04    30.000000
# max      19.000000  7.815831e+07  1000.000000

# %% [markdown]
# We can see the maximum value in Rating column which is 19.  Rating can't be 19. It will be 1 to 5, So, This value is wrong here.

# %%
df_play_store.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content_Rating  \
# 0      159  19.0      10,000+  Free     0       Everyone
# 1      967  14.0     500,000+  Free     0       Everyone
# 2    87510   8.7   5,000,000+  Free     0       Everyone
# 3   215644  25.0  50,000,000+  Free     0           Teen
# 4      967   2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last_Updated         Current_Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android_Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
#For finding the null values in unique column
df_play_store.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content_Rating       1
# Genres               0
# Last_Updated         0
# Current_Ver          8
# Android_Ver          3
# dtype: int64

# %%
#Finding total null values in dataset
df_play_store.isnull().sum().sum()
# Out:
# 3182

# %%
#Finding unique values
df_play_store.nunique()
# Out:
# App               9660
# Category            34
# Rating              40
# Reviews           6001
# Size               460
# Installs            22
# Type                 3
# Price               93
# Content_Rating       6
# Genres             120
# Last_Updated      1378
# Current_Ver       2832
# Android_Ver         33
# dtype: int64

# %% [markdown]
# We can see the Type column and Content Rating value have less number number of values

# %% [markdown]
# ####2. User Review Data

# %%
df_user_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37427 entries, 0 to 64230
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     37427 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37427 non-null  object
#  3   Sentiment_Polarity      37427 non-null  float64
#  4   Sentiment_Subjectivity  37427 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.7+ MB

# %%
df_user_review.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37427.000000            37427.000000
# mean             0.182171                0.492770
# std              0.351318                0.259904
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
df_user_review.head(5)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
#For finding the null values in unique column
df_user_review.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
#Finding total null values in dataset
df_user_review.isnull().sum().sum()
# Out:
# 0

# %%
#Finding unique values
df_user_review.nunique()
# Out:
# App                        1074
# Translated_Review         27994
# Sentiment                     3
# Sentiment_Polarity         5410
# Sentiment_Subjectivity     4474
# dtype: int64

# %% [markdown]
# We can see the Sentiment column value have less number number of values

# %% [markdown]
# ###Step4: Cleaning the Data

# %% [markdown]
# ####1. Play Store Data

# %%
#replacing spaces in column names with "-" to access it without errors
df_play_store.columns=[each.replace(" ","_") for each in df_play_store.columns]

# %% [markdown]
# #####Review Column

# %% [markdown]
# The review column have object as a data type. We will convert it into int data type

# %%
df_play_store.Reviews = df_play_store.Reviews.apply(lambda x: float(str(x).replace('M', '')) if 'M' in str(x) else x) 
df_play_store.Reviews = df_play_store.Reviews.apply(lambda x:int(x))

# %%
#To verify the  null value
df_play_store['Reviews'].isna().any()
# Out:
# False

# %%
#To verify the data type
df_play_store['Reviews'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ##### Size Column

# %% [markdown]
# We observed that Size column contains the Strings or characters such as "MB", "KB", ",","+" and "Varies with device".

# %%
#We will convert this to float.
df_play_store['Size'] = df_play_store['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)
df_play_store['Size'] = df_play_store['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
df_play_store['Size'] = df_play_store['Size'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else x)
df_play_store['Size'] = df_play_store['Size'].apply(lambda x: float(str(x).replace('k', ''))/1024 if 'k' in str(x) else x) #1MB= 1024KB
df_play_store['Size'] = df_play_store['Size'].apply(lambda x: str(x).replace('+','') if '+' in str(x) else x)
df_play_store['Size'] = df_play_store['Size'].apply(lambda x: float(x))

# %%
#One thing is that, Size can't be zero. So we will check it using describe method and also we can verify data type
df_play_store['Size'].describe()
# Out:
# count    9146.000000
# mean       21.623150
# std        24.797055
# min         0.008301
# 25%         4.900000
# 50%        13.000000
# 75%        30.000000
# max      1000.000000
# Name: Size, dtype: float64

# %% [markdown]
# Here, Minimum value is not zero

# %%
#To check if it contains null values
df_play_store[df_play_store['Size'].isna()]
# Out:
#                                                      App             Category  \
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# ...                                                  ...                  ...
# 10713  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10725                                          Posta App  MAPS_AND_NAVIGATION
# 10765                    Chat For Strangers - Video Chat               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
#        Rating  Reviews  Size    Installs  Type  Price Content_Rating  \
# 37        4.1    36639   NaN   5000000.0  Free    0.0       Everyone
# 42        4.4   295221   NaN  10000000.0  Free    0.0       Everyone
# 52        4.6    17057   NaN   1000000.0  Free    0.0       Everyone
# 67        4.3    40211   NaN   5000000.0  Free    0.0       Everyone
# 68        3.9      356   NaN    100000.0  Free    0.0       Everyone
# ...       ...      ...   ...         ...   ...    ...            ...
# 10713     4.4     3471   NaN    100000.0  Free    0.0       Everyone
# 10725     3.6        8   NaN      1000.0  Free    0.0       Everyone
# 10765     3.4      622   NaN    100000.0  Free    0.0     Mature 17+
# 10826     4.0    88486   NaN   5000000.0  Free    0.0     Mature 17+
# 10839     4.5      114   NaN      1000.0  Free    0.0     Mature 17+
#
#                   Genres        Last_Updated         Current_Ver  \
# 37          Art & Design       July 14, 2018  Varies with device
# 42          Art & Design       July 30, 2018  Varies with device
# 52       Auto & Vehicles       July 30, 2018  Varies with device
# 67       Auto & Vehicles       July 30, 2018  Varies with device
# 68       Auto & Vehicles        May 25, 2018  Varies with device
# ...                  ...                 ...                 ...
# 10713            Weather       July 24, 2018  Varies with device
# 10725  Maps & Navigation  September 27, 2017  Varies with device
# 10765             Social        May 23, 2018  Varies with device
# 10826             Social      March 23, 2018  Varies with device
# 10839  Books & Reference    January 19, 2015  Varies with device
#
#               Android_Ver
# 37           2.3.3 and up
# 42     Varies with device
# 52     Varies with device
# 67     Varies with device
# 68     Varies with device
# ...                   ...
# 10713  Varies with device
# 10725          4.4 and up
# 10765  Varies with device
# 10826  Varies with device
# 10839  Varies with device
#
# [1695 rows x 13 columns]

# %%
# replacing null value in Size column with Mean
df_play_store['Size'].fillna(value=20.35, inplace = True)

# %% [markdown]
# #####Installs column

# %%
# Installs column contains the "+","," and "Free". So we will remove "+","," and replace "Free" with "NaN"
df_play_store['Installs'] = df_play_store['Installs'].apply(lambda x: str(x).replace('Free', 'NaN') if 'Free' in str(x) else x)
df_play_store['Installs'] = df_play_store['Installs'].apply(lambda x: str(x).replace('+', '') if '+' in str(x) else x)
df_play_store['Installs'] = df_play_store['Installs'].apply(lambda x: str(x).replace(',', '') if ',' in str(x) else x)
df_play_store['Installs']=df_play_store['Installs'].apply(lambda x: float(x))

# %%
#We will check how minimum and maximum number of app installs and also data type
df_play_store['Installs'].describe()
# Out:
# count    1.084000e+04
# mean     1.546434e+07
# std      8.502936e+07
# min      0.000000e+00
# 25%      1.000000e+03
# 50%      1.000000e+05
# 75%      5.000000e+06
# max      1.000000e+09
# Name: Installs, dtype: float64

# %% [markdown]
# #####Price Column

# %%
#Price column have data type object. So, We observed that there are two values minimum and maximum which are not int or float
df_play_store['Price'].min(),df_play_store['Price'].max()
# Out:
# ('$0.99', 'Everyone')

# %%
#We will replace "Everyone" with "NaN"
df_play_store['Price'] = df_play_store['Price'].apply(lambda x: str(x).replace('Everyone', 'NaN') if 'Everyone' in str(x) else x)
df_play_store['Price'] = df_play_store['Price'].apply(lambda x: str(x).replace('$','') if '$' in str(x) else x)
df_play_store['Price'] = df_play_store['Price'].apply(lambda x: str(x).replace(' ','') if ' ' in str(x) else x)
df_play_store['Price']=df_play_store['Price'].apply(lambda x: float(x))

# %%
#To check minimum & maximum price and also to verify data type
df_play_store['Price'].describe()
# Out:
# count    10840.000000
# mean         1.027368
# std         15.949703
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        400.000000
# Name: Price, dtype: float64

# %%
df_play_store.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             1
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# Installs1            0
# dtype: int64

# %% [markdown]
# #####Rating Column

# %%
#To understand the description
df_play_store['Rating'].describe()
# Out:
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64

# %% [markdown]
# As we know, rating should be between 1 to 5. But here we can see max value 19. So, This is outlier here.
# We will check the rating column values which are greater than 5

# %%
df_play_store[df_play_store['Rating']>5]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0        3
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1000.0       NaN    0    NaN            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver Installs1
# 10472       1.0.19  4.0 and up         NaN      Free

# %% [markdown]
# Only one value is there and also some of other column values are NaN. So, We will drop it.

# %%
df_play_store.drop([10472],inplace= True)

# %%
df_play_store.describe()
# Out:
#             Rating       Reviews         Size      Installs         Price
# count  9366.000000  1.084000e+04  9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05    21.516165  1.546434e+07      1.027368
# std       0.515219  2.927761e+06    22.589084  8.502936e+07     15.949703
# min       1.000000  0.000000e+00     0.008301  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01     4.900000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03    13.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04    30.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09    400.000000

# %% [markdown]
# #####Type Column

# %%
df_play_store.describe()
# Out:
#             Rating       Reviews         Size      Installs         Price
# count  9366.000000  1.084000e+04  9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05    21.516165  1.546434e+07      1.027368
# std       0.515219  2.927761e+06    22.589084  8.502936e+07     15.949703
# min       1.000000  0.000000e+00     0.008301  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01     4.900000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03    13.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04    30.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09    400.000000

# %%
df_play_store['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %% [markdown]
# There are only 3 values

# %%
# We will replace NaN values with free and greater than zero with paid
df_play_store.loc[df_play_store.Price == 0, 'Type'] = "Free"
df_play_store.loc[df_play_store.Price > 0, 'Type'] = "Paid"

# %%
#It's just to verify
df_play_store.Type.unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %% [markdown]
# #####Android_Ver column

# %%
df_play_store.describe()
# Out:
#             Rating       Reviews          Size      Installs         Price
# count  9366.000000  1.084000e+04  10840.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05     21.333818  1.546434e+07      1.027368
# std       0.515219  2.927761e+06     20.752127  8.502936e+07     15.949703
# min       1.000000  0.000000e+00      0.008301  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01      5.900000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03     18.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04     26.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07    100.000000  1.000000e+09    400.000000

# %%
df_play_store[df_play_store['Android_Ver'].isna()]
# Out:
#                          App         Category  Rating  Reviews  Size  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4      230  11.0
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5      189   2.1
#
#       Installs  Type  Price Content_Rating           Genres    Last_Updated  \
# 4453    1000.0  Paid   1.49       Everyone  Personalization   July 20, 2018
# 4490   10000.0  Free   0.00       Everyone  Personalization  March 27, 2018
#
#      Current_Ver Android_Ver
# 4453         4.4         NaN
# 4490         1.1         NaN

# %%
# Replace the null values with mode
df_play_store['Android_Ver'].fillna('4.1 and up', inplace = True)

# %% [markdown]
# #####Current_Ver column

# %%
df_play_store['Current_Ver'].describe()
# Out:
# count                  10832
# unique                  2831
# top       Varies with device
# freq                    1459
# Name: Current_Ver, dtype: object

# %%
df_play_store[df_play_store['Current_Ver'].isna()]
# Out:
#                                    App             Category  Rating  Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2       55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1    20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2     4010
# 6803                         BT Master               FAMILY     4.3        0
# 7333                       Dots puzzle               FAMILY     4.0      179
# 7407                   Calculate My IQ               FAMILY     4.3       44
# 7730                            UFO-CQ                TOOLS     4.3        1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     4.3        8
#
#             Size   Installs  Type  Price Content_Rating             Genres  \
# 15      2.700000     5000.0  Free   0.00       Everyone       Art & Design
# 1553    0.010742  1000000.0  Free   0.00       Everyone   Libraries & Demo
# 6322    8.700000   500000.0  Free   0.00       Everyone              Tools
# 6803    0.216797      100.0  Free   0.00       Everyone          Education
# 7333   14.000000    50000.0  Paid   0.99       Everyone             Puzzle
# 7407    7.200000    10000.0  Free   0.00       Everyone      Entertainment
# 7730    0.231445       10.0  Paid   0.99       Everyone              Tools
# 10342   0.642578     1000.0  Free   0.00       Everyone  Books & Reference
#
#             Last_Updated Current_Ver Android_Ver   Installs1
# 15          June 6, 2018         NaN  4.2 and up      5,000+
# 1553   February 12, 2013         NaN  1.5 and up  1,000,000+
# 6322        May 10, 2017         NaN  4.0 and up    500,000+
# 6803    November 6, 2016         NaN  1.6 and up        100+
# 7333      April 18, 2018         NaN  4.0 and up     50,000+
# 7407       April 3, 2017         NaN  2.3 and up     10,000+
# 7730        July 4, 2016         NaN  2.0 and up         10+
# 10342   January 31, 2017         NaN  3.0 and up      1,000+

# %%
# replace the null values with mode
df_play_store['Current_Ver'].fillna('Varies with device', inplace = True)

# %% [markdown]
# #####Check if any column is null

# %%
df_play_store.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content_Rating       0
# Genres               0
# Last_Updated         0
# Current_Ver          0
# Android_Ver          0
# dtype: int64

# %% [markdown]
# ####2. User review data

# %%
df_user_review.isna().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
df_user_review.Sentiment.unique()
# Out:
# array(['Positive', nan, 'Neutral', 'Negative'], dtype=object)

# %%
df_user_review.loc[df_user_review['Sentiment'].isna() & df_user_review['Sentiment_Polarity'].isna()]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# 102                   NaN                     NaN
# 107                   NaN                     NaN
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [26863 rows x 5 columns]

# %% [markdown]
# We can see lot of null values present in this data

# %%
# drop null values from dataset

df_user_review.dropna(inplace=True)

# %%
df_user_review.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37427.000000            37427.000000
# mean             0.182171                0.492770
# std              0.351318                0.259904
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ## **Merging two dataset**

# %%
merged_df = df_play_store.merge(df_user_review, on="App")

# %%
merged_df.head(10)
# Out:
#                    App        Category  Rating  Reviews  Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 5  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 6  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 7  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 8  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 9  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
#
#    Price Content_Rating                     Genres      Last_Updated  \
# 0    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 5    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 6    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 7    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 8    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 9    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current_Ver   Android_Ver  \
# 0       2.0.0  4.0.3 and up
# 1       2.0.0  4.0.3 and up
# 2       2.0.0  4.0.3 and up
# 3       2.0.0  4.0.3 and up
# 4       2.0.0  4.0.3 and up
# 5       2.0.0  4.0.3 and up
# 6       2.0.0  4.0.3 and up
# 7       2.0.0  4.0.3 and up
# 8       2.0.0  4.0.3 and up
# 9       2.0.0  4.0.3 and up
#
#                                    Translated_Review Sentiment  \
# 0  A kid's excessive ads. The types ads allowed a...  Negative
# 1                                         It bad >:(  Negative
# 2                                               like   Neutral
# 3                           I love colors inspyering  Positive
# 4                                             I hate  Negative
# 5                                           omgggggg   Neutral
# 6                                           It cute.  Positive
# 7                                             I love  Positive
# 8                                               Love  Positive
# 9                               I love enjoyable fun  Positive
#
#    Sentiment_Polarity  Sentiment_Subjectivity
# 0           -0.250000                1.000000
# 1           -0.725000                0.833333
# 2            0.000000                0.000000
# 3            0.500000                0.600000
# 4           -0.800000                0.900000
# 5            0.000000                0.000000
# 6            0.500000                1.000000
# 7            0.500000                0.600000
# 8            0.500000                0.600000
# 9            0.433333                0.466667

# %% [markdown]
# In merged dataframe you can see we have 4 new columns Translated_Review, Sentiment,Sentiment_Polarity, Sentiment_Subjectivity

# %% [markdown]
# # **DATA VISUALIZATION**

# %% [markdown]
# #  Correlation Map
# ### Correlation measures the relationship between two variables.

# %%
matrix = merged_df.corr()
print("Correlation matrix is : ")
print(matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-def12fc274e4> in <module>()
# ----> 1 matrix = merged_df.corr()
#       2 print("Correlation matrix is : ")
#       3 print(matrix)
#
# NameError: name 'merged_df' is not defined
